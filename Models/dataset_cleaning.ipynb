# %%
from datasets import load_dataset
import re

# %%
##Loading in the dataset
ds = load_dataset("Exorde/exorde-social-media-december-2024-week1")
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['date', 'original_text', 'url', 'author_hash', 'language', 'primary_theme', 'english_keywords', 'sentiment', 'main_emotion', 'secondary_themes'],
#         num_rows: 65542211
#     })
# })

# %%
##Function to remove hyperlinks, spaces and emojis from text
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+|@\w+|#\w+|[^\x00-\x7F]+", " ", text)  # Removing url using regex on HTTP, @ regex mentions, and emoji code regex patterns
    text = re.sub(r"[^a-z\s]", "", text)                          # Letter Only Regex
    text = re.sub(r"\s+", " ", text).strip()                     # Space Trim Logic
    return text

# %%
##Filter to English only inputs - choosing 10,000 as we still need to account for removing emojis, etc.
##This will generate the X dataset, replace with any social media platform domain to generate same dataset for other platforms  
en_ds = ds['train'].filter(lambda example: example['language'] == 'en' and example['url'].startswith('https://x.com/') and clean_text(example.get('original_text', '')) != '')
sample_en_ds = en_ds.shuffle(seed=42).select(range(min(5000, len(en_ds))))
sample_en_ds = sample_en_ds.map(lambda example: {**example, 'cleaned_text': clean_text(example.get('original_text', ''))})
sample_en_df = sample_en_ds.to_pandas()
sample_en_df
# Out:
# Map: 100%|██████████| 5000/5000 [00:04<00:00, 1004.34 examples/s]
#                           date  \
# 0     2024-12-03T18:13:09.000Z
# 1     2024-12-07T05:07:31.000Z
# 2     2024-12-04T04:00:06.000Z
# 3     2024-12-06T23:02:22.000Z
# 4     2024-12-02T23:35:56.000Z
# ...                        ...
# 4995  2024-12-01T15:41:01.000Z
# 4996  2024-12-04T00:04:58.000Z
# 4997  2024-12-01T16:34:08.000Z
# 4998  2024-12-02T06:47:46.000Z
# 4999  2024-12-05T12:27:21.000Z
#
#                                           original_text  \
# 0     They make us realize we have other options . T...
# 1     This is how Grok2 AI represents this scenario....
# 2     I a pretty sure it may have been because they ...
# 3     Check out R! It's the most underrated programm...
# 4     I came to this car just knowing I was about to...
# ...                                                 ...
# 4995  i think $20 is enough for my cat's health main...
# 4996        Sure your mom's ass is getting pretty messy
# 4997  Joo Bayden no fodii waɗude njillu jaango Altin...
# 4998             ARE THERE ANY WINGS U DONT MIND GIVING
# 4999  All \n@abbydphillip\n done is play a really ba...
#
#                                                     url  \
# 0     https://x.com/DarrylRoss72/status/186400999686...
# 1     https://x.com/5L4Y3R_0F_D00M/status/1865261836...
# 2     https://x.com/Chrishall05/status/1864157706342...
# 3     https://x.com/nrachabathuni/status/18651699426...
# 4     https://x.com/_jayywalker/status/1863728840939...
# ...                                                 ...
# 4995  https://x.com/0xdreawins/status/18632469342046...
# 4996  https://x.com/Astonedgoodboi/status/1864098533...
# 4997    https://x.com/RFI_Ff/status/1863260301799625048
# 4998  https://x.com/rec0v3r3d/status/186347512716745...
# 4999   https://x.com/6nsinvt/status/1864647749708173757
#
#                                    author_hash language   primary_theme  \
# 0     f14ec6948ee11dedce31054f4127a4c24c42b7ec       en          People
# 1                                         None       en      Technology
# 2                                         None       en          Sports
# 3     913df5d294a176a797b8b4f5b4ad5a72927a751e       en      Technology
# 4     25e3b6f98cbdea5f4715aec413139574f84b806f       en     Environment
# ...                                        ...      ...             ...
# 4995                                      None       en          Health
# 4996                                      None       en     Environment
# 4997  7a9ec4a656efb945ff4eacc8b28cbe6da7ba62f1       en  Cryptocurrency
# 4998                                      None       en          People
# 4999  8848b2e54ed3619ad162a9a3eb8e2cd201db5449       en   Entertainment
#
#                                        english_keywords  sentiment  \
# 0     saturday, delivering, make, realize, options d...      -0.18
# 1     varahavtar, grok2, badass, missed, scenario, y...      -0.05
# 2                                    undefeated, pretty      -0.04
# 3     data analysis, statistics, datascience, underr...       0.18
# 4     i’m, car, home smh, home, cold, knowing, smh, ...      -0.62
# ...                                                 ...        ...
# 4995  cat, cat health, health maintenance, parvo, he...      -0.07
# 4996     mom ass, ass, pretty, mom, messy, pretty messy      -0.13
# 4997  fodii waɗude, jaango, fodii, bayden, jaango al...      -0.16
# 4998  DONT, there, GIVING, wings, dont, ANY, DONT MI...       0.01
# 4999  trump evil, evil, STAGED, nightly cage, cnn, s...      -0.86
#
#      main_emotion secondary_themes  \
# 0     realization           [2, 7]
# 1         neutral           [3, 7]
# 2        approval        [8, 3, 7]
# 3         neutral           [3, 7]
# 4         neutral       [10, 3, 7]
# ...           ...              ...
# 4995      sadness        [3, 4, 7]
# 4996    annoyance       [10, 3, 7]
# 4997      neutral        [9, 3, 7]
# 4998      neutral        [2, 3, 7]
# 4999      neutral       [3, 14, 7]
#
#                                            cleaned_text
# 0     they make us realize we have other options the...
# 1     this is how grok ai represents this scenario y...
# 2     i a pretty sure it may have been because they ...
# 3     check out r its the most underrated programmin...
# 4     i came to this car just knowing i was about to...
# ...                                                 ...
# 4995  i think is enough for my cats health maintenan...
# 4996         sure your moms ass is getting pretty messy
# 4997  joo bayden no fodii wa ude njillu jaango altin...
# 4998             are there any wings u dont mind giving
# 4999  all done is play a really bad referee in her n...
#
# [5000 rows x 11 columns]

# %%
##Save to a .csv
sample_en_df.to_csv('x_en_dataset.csv', index=False)
